# %% [markdown]
# # **Import Modules and Libraries**

# %% [markdown]
# ## *Python*

# %%
import os
import sys

# %% [markdown]
# ## *Custom*

# %%
#import customised modules

#define path
sys.path.append(os.path.abspath(os.path.join('..')))

##import relevant modules
from scripts.sentiment_thematic_analysis import dfloader_and_analyser
# Out:
# Device set to use cpu

# %%
#select folder to save the processed DataFrame and plots
output_folder = os.path.join(os.path.dirname(os.getcwd()), 'data')
plot_folder = os.path.join(os.path.dirname(os.getcwd()), 'plot_images')

# %% [markdown]
# # **Bank of Abyssinia**

# %%
df_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'Abyssinia_reviews_processed.csv')
load = dfloader_and_analyser(df_path, 'Abyssinia', output_folder,plot_folder=plot_folder)
# Out:
# Sentiment Value Counts Plot:
#
# Plot is saved to ..\plot_images\Abyssinia - Sentiment Distribution.png.
# Aggregated Results:
#    bank_name  rating     score
# 0  Abyssinia       1  0.973660
# 1  Abyssinia       2  0.935956
# 2  Abyssinia       3  0.957500
# 3  Abyssinia       4  0.955930
# 4  Abyssinia       5  0.956644
#
# TF-IDF Matrix Shape: (499, 1000)
# Feature Names: ['ab' 'abdu' 'abdu mudesr' 'abdulkadir' 'abessnya' 'abessnya banke'
#  'abissena' 'abissinya' 'able' 'able find' 'able solve' 'able use'
#  'absurd' 'absurd avoid' 'abyssinia' 'abyssinia bank' 'access'
#  'access account' 'account' 'activate' 'active' 'actual' 'actually' 'add'
#  'allow']
#
# Top Keywords in Positive Reviews: ['amazing' 'app' 'application' 'bank' 'banking' 'boa' 'ethiopia'
#  'excellent' 'fast' 'good' 'great' 'like' 'nice' 'ok' 'service' 'thank'
#  'use' 'well' 'work' 'wow']
#
#  Top Keywords in Negative Reviews: ['app' 'bad' 'bank' 'banking' 'boa' 'crash' 'developer' 'fix' 'mobile'
#  'money' 'need' 'open' 'option' 'slow' 'time' 'transaction' 'update' 'use'
#  'well' 'work']
#
# Plot is saved to ..\plot_images\Abyssinia -Word Cloud for Positive Reviews.png.
# Plot is saved to ..\plot_images\Abyssinia - Word Cloud for Negative Reviews.png.
# Processed DataFrame Saved to: ..\data\Abyssinia_result.csv
#
# DataFrame Head:
#          date  rating                                        review_text  \
# 0  2025-06-05       3                                   it's not working
# 1  2025-06-03       1  Hello, I’m facing a problem with the BOA Mobil...
# 2  2025-06-03       5                                        exceptional
# 3  2025-06-02       5                               BoA Mobile good bank
# 4  2025-06-01       1                    this is worest app 24/7 loading
#
#   sentiment     score                                     spacy_keywords  \
# 0  NEGATIVE  0.999786
# 1  NEGATIVE  0.999415  problem, BOA, Mobile, app, time, phone, number...
# 2  POSITIVE  0.999851                                        exceptional
# 3  POSITIVE  0.998473                            BoA, Mobile, good, bank
# 4  NEGATIVE  0.993474                                  wor, app, loading
#
#      identified_theme(s)  bank_name
# 0                  Other  Abyssinia
# 1  Account Access Issues  Abyssinia
# 2                  Other  Abyssinia
# 3                  Other  Abyssinia
# 4                  Other  Abyssinia

# %% [markdown]
# # **Commercial Bank of Ethiopia**

# %%
df_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'Commercial_reviews_processed.csv')
load = dfloader_and_analyser(df_path, 'Commercial', output_folder=output_folder,plot_folder=plot_folder)
# Out:
# Sentiment Value Counts Plot:
#
# Plot is saved to ..\plot_images\Commercial - Sentiment Distribution.png.
# Aggregated Results:
#     bank_name  rating     score
# 0  Commercial       1  0.966707
# 1  Commercial       2  0.982848
# 2  Commercial       3  0.977027
# 3  Commercial       4  0.960563
# 4  Commercial       5  0.976277
#
# TF-IDF Matrix Shape: (484, 1000)
# Feature Names: ['abank mean' 'able' 'able screenshot' 'absolutely' 'absolutely fantastic'
#  'absolutely good' 'access' 'access app' 'access bank' 'access banking'
#  'access developer' 'access old' 'access reason' 'access recent'
#  'accessible' 'account' 'add' 'ahead' 'allow' 'allow screenshot' 'amazing'
#  'amazing app' 'annoying' 'app' 'app app']
#
# Top Keywords in Positive Reviews: ['amazing' 'app' 'application' 'bank' 'banking' 'cbe' 'easy' 'excellent'
#  'fast' 'good' 'great' 'like' 'mobile' 'nice' 'ok' 'reliable' 'thank'
#  'use' 'well' 'wow']
#
#  Top Keywords in Negative Reviews: ['account' 'app' 'application' 'bank' 'banking' 'cbe' 'developer' 'fix'
#  'good' 'like' 'mobile' 'money' 'need' 'screenshot' 'time' 'transaction'
#  'transfer' 'update' 'work' 'ነው']
#
# Plot is saved to ..\plot_images\Commercial -Word Cloud for Positive Reviews.png.
# Plot is saved to ..\plot_images\Commercial - Word Cloud for Negative Reviews.png.
# Processed DataFrame Saved to: ..\data\Commercial_result.csv
#
# DataFrame Head:
#          date  rating                                        review_text  \
# 0  2025-06-06       4  "Why don’t your ATMs support account-to-accoun...
# 1  2025-06-05       1                        what is this app problem???
# 2  2025-06-05       5       the app is proactive and a good connections.
# 3  2025-06-05       3    I cannot send to cbebirr app. through this app.
# 4  2025-06-05       4                                               good
#
#   sentiment     score                                     spacy_keywords  \
# 0  NEGATIVE  0.996465  atm, account, account, transfer, country, Keny...
# 1  NEGATIVE  0.999623                                       app, problem
# 2  POSITIVE  0.999868                   app, proactive, good, connection
# 3  NEGATIVE  0.995335                                  cbebirr, app, app
# 4  POSITIVE  0.999816                                               good
#
#      identified_theme(s)   bank_name
# 0  Account Access Issues  Commercial
# 1                  Other  Commercial
# 2                  Other  Commercial
# 3                  Other  Commercial
# 4                  Other  Commercial

# %% [markdown]
# # **Dashen Bank**

# %%
df_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'Dashen_reviews_processed.csv')
load = dfloader_and_analyser(df_path, 'Dashen', output_folder=output_folder, plot_folder=plot_folder)
# Out:
# Sentiment Value Counts Plot:
#
# Plot is saved to ..\plot_images\Dashen - Sentiment Distribution.png.
# Aggregated Results:
#   bank_name  rating     score
# 0    Dashen       1  0.995235
# 1    Dashen       2  0.960082
# 2    Dashen       3  0.997640
# 3    Dashen       4  0.975197
# 4    Dashen       5  0.985542
#
# TF-IDF Matrix Shape: (447, 1000)
# Feature Names: ['able' 'able access' 'able budget' 'able chat' 'able information'
#  'able pay' 'able payment' 'able transfer' 'absolutely' 'absolutely love'
#  'absolutely speed' 'acc' 'acc acc' 'acc bank' 'accept' 'accept yemilew'
#  'access' 'access account' 'accessible' 'account' 'account statement'
#  'activate' 'actually' 'add' 'add option']
#
# Top Keywords in Positive Reviews: ['ahead' 'amazing' 'app' 'application' 'bank' 'banking' 'dashen' 'digital'
#  'easy' 'experience' 'fast' 'feature' 'friendly' 'good' 'payment' 'step'
#  'super' 'transaction' 'use' 'user']
#
#  Top Keywords in Negative Reviews: ['account' 'app' 'application' 'bank' 'banking' 'dashen' 'developer'
#  'experience' 'feature' 'good' 'like' 'need' 'send' 'slow' 'telebirr'
#  'time' 'transaction' 'transfer' 'work' 'ነው']
#
# Plot is saved to ..\plot_images\Dashen -Word Cloud for Positive Reviews.png.
# Plot is saved to ..\plot_images\Dashen - Word Cloud for Negative Reviews.png.
# Processed DataFrame Saved to: ..\data\Dashen_result.csv
#
# DataFrame Head:
#          date  rating                          review_text sentiment  \
# 0  2025-06-06       3                                 love  POSITIVE
# 1  2025-06-03       5                                 መቸሸጠ  NEGATIVE
# 2  2025-06-03       5                                  wow  POSITIVE
# 3  2025-06-01       5                                gadaa  NEGATIVE
# 4  2025-05-31       5  Massive upgrade from the Amole app.  POSITIVE
#
#       score                spacy_keywords identified_theme(s) bank_name
# 0  0.999874                          love               Other    Dashen
# 1  0.697057                          መቸሸጠ               Other    Dashen
# 2  0.999592                                             Other    Dashen
# 3  0.721146                         gadaa               Other    Dashen
# 4  0.964642  massive, upgrade, Amole, app               Other    Dashen
